# %%
import pandas as pd
import seaborn as sn
data = pd.read_csv('twitter_dataset.csv')

# %% [markdown]
# Diagrama de cajas para cada columna

# %%
data.plot(y="Tweet_ID", kind='box')
# Out:
# <Axes: >

# %%
data.plot(y="Retweets", kind='box')
# Out:
# <Axes: >

# %%
data.plot(y="Likes", kind='box')
# Out:
# <Axes: >

# %%
data.plot(y="Tweet_ID", kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(y="Retweets", kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(y="Likes", kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
numeric_data = data[['Tweet_ID', 'Retweets', 'Likes']]
corr = numeric_data.corr()
sn.heatmap(corr, annot = True)
# Out:
# <Axes: >
